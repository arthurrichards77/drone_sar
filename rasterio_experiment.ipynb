# %%
import os
import rasterio
from rasterio.plot import show
from matplotlib import pyplot

# %%
big_map = rasterio.open('llanbedr_rgb.tif')

# %%
big_map.colorinterp[:]
# Out:
# (<ColorInterp.red: 3>, <ColorInterp.green: 4>, <ColorInterp.blue: 5>)

# %%
show(big_map)
# Out:
# <AxesSubplot: >

# %%
big_map.bounds
# Out:
# BoundingBox(left=250000.0, bottom=320000.0, right=260000.0, top=330000.0)

# %%
big_map.dataset_mask()
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)
